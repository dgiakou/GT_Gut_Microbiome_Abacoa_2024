# %%
import pandas as pd
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.colors as mcolors

# Load the data
df = pd.read_excel('/Users/dimitriosgiakoumas/Downloads/Shannon_Rarefraction.xlsx')

# Compute average curve
average_curve = df.groupby('sequences per sample').mean()

# Create a color palette
rgb_colors = sns.color_palette('Spectral', len(average_curve.columns))
hex_colors = [mcolors.rgb2hex(color) for color in rgb_colors]
sns.color_palette()
# Create a new figure
fig = go.Figure()

# Add a line for each sample with a specific color
for i, column in enumerate(average_curve.columns):
    fig.add_trace(go.Scatter(x=average_curve.index, y=average_curve[column], mode='lines',
                             name=f'{column}', line=dict(color=hex_colors[i], width=2)))

# Update layout
fig.update_layout(title='Rarefaction Curve',
                  xaxis_title='Sequences per Sample',
                  yaxis_title='Shannon Alpha Diversity',
                  autosize=True,
                  width=1200,
                  height=800,
                  legend=dict(yanchor="top",
                              y=-0.1,
                              xanchor="center",
                              x=0.5,
                              orientation="h"),
                  )

# Save the plot as a .tif file with 300 dpi to the specified directory
# save_path = '/Users/dimitriosgiakoumas/Library/CloudStorage/OneDrive-FloridaAtlanticUniversity/biplot.tif'
# plt.savefig(save_path, format='tiff', dpi=300)


fig.show()
# Out:
# <div>                            <div id="5034a7d0-e279-4e2b-9839-8b80bec56d17" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5034a7d0-e279-4e2b-9839-8b80bec56d17")) {                    Plotly.newPlot(                        "5034a7d0-e279-4e2b-9839-8b80bec56d17",                        [{"line":{"color":"#b11747","width":2},"mode":"lines","name":"T20","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.174379219868,7.34616299523,7.523697791546001,7.57667011072,7.622552447526999,7.633479172922,7.6417659597080005,7.647765531418,7.655328577762999,7.668492237542,7.675793746982],"type":"scatter"},{"line":{"color":"#c52c4b","width":2},"mode":"lines","name":"T107","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.1743792198680003,8.247793317405,8.437989593912,8.514441625589999,8.547955472735,8.57930696585,8.601594843418999,8.594029861536,8.610374177389,8.619495074629999,8.625527268089],"type":"scatter"},{"line":{"color":"#d8434e","width":2},"mode":"lines","name":"T203","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.2019280948899995,8.036836128327,8.193505309584001,8.252386751223,8.285875631515001,8.311545293974,8.320758402809,8.325668527629,8.330022720512,8.344124716848,8.344361444521],"type":"scatter"},{"line":{"color":"#e3534a","width":2},"mode":"lines","name":"T11","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.26192809489,8.054718071263,8.233389477852999,8.282081838029999,8.315354349126,8.345181192534,8.343392854187,8.367830307053001,8.37636888415,8.379111798941,8.380312421668],"type":"scatter"},{"line":{"color":"#ef6645","width":2},"mode":"lines","name":"T212","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.2143792198680003,7.698166018591,7.8397330922210005,7.896905924524001,7.946352841184,7.955063333236,7.970790424521001,7.970772438537,7.978733340674999,7.985928154701,7.995286372771],"type":"scatter"},{"line":{"color":"#f67a49","width":2},"mode":"lines","name":"T85.1","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.14192809489,8.115184039275,8.273411506598,8.34296332271,8.371934255861001,8.396910967015,8.41291182325,8.424613592823999,8.437591477603,8.432808517724999,8.447514027587001],"type":"scatter"},{"line":{"color":"#f99355","width":2},"mode":"lines","name":"T65","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.26192809489,8.102441762797,8.275859920992,8.353857488411,8.388330413829,8.411607790926,8.44144237682,8.43745199626,8.461171758564,8.458509002956,8.467780107695],"type":"scatter"},{"line":{"color":"#fcaa5f","width":2},"mode":"lines","name":"T196","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.28192809489,8.184389780802999,8.330590102684999,8.389093933107999,8.437931540385,8.463262251116001,8.465053780594001,8.476385096927,8.482284977854,8.488646005022,8.495720287712],"type":"scatter"},{"line":{"color":"#fdbf6f","width":2},"mode":"lines","name":"T99","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.2543792198680004,8.343439660305,8.550119880354,8.651347174396,8.703243226629999,8.718924727867,8.736399361646999,8.749152621877,8.765266783659,8.778880694125,8.77693445708],"type":"scatter"},{"line":{"color":"#fed07e","width":2},"mode":"lines","name":"T85.2","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.2419280948900004,8.266721504848999,8.450061915195999,8.549725229856,8.579001431707999,8.607801972333,8.616575732231,8.634579128486,8.651046168758,8.649587907482,8.669501613228],"type":"scatter"},{"line":{"color":"#fee28f","width":2},"mode":"lines","name":"TAK","x":[10,2009,4008,6007,8006,10005,12004,14003,16002,18001,20000],"y":[3.114379219868,7.2045750 ...

# %%
from PIL import Image

# Open the PNG file
png_path = '/Users/dimitriosgiakoumas/Library/CloudStorage/OneDrive-FloridaAtlanticUniversity/rarefraction.png'
with Image.open(png_path) as im:
    # Convert to TIFF format
    tiff_path = '/Users/dimitriosgiakoumas/Library/CloudStorage/OneDrive-FloridaAtlanticUniversity/rarefraction.tiff'
    im.save(tiff_path, format='TIFF')
